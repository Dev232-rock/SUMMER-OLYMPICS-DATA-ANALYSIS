# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("USA_cars_datasets.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand  ...       state  country      condition
# 0           0   6300     toyota  ...  new jersey      usa   10 days left
# 1           1   2899       ford  ...   tennessee      usa    6 days left
# 2           2   5350      dodge  ...     georgia      usa    2 days left
# 3           3  25000       ford  ...    virginia      usa  22 hours left
# 4           4  27700  chevrolet  ...     florida      usa  22 hours left
#
# [5 rows x 13 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand  ...       state  country      condition
# 0           0   6300     toyota  ...  new jersey      usa   10 days left
# 1           1   2899       ford  ...   tennessee      usa    6 days left
# 2           2   5350      dodge  ...     georgia      usa    2 days left
# 3           3  25000       ford  ...    virginia      usa  22 hours left
# 4           4  27700  chevrolet  ...     florida      usa  22 hours left
#
# [5 rows x 13 columns]

# %%
df['country'].unique()
# Out:
# array([' usa', ' canada'], dtype=object)

# %%
df['price'].unique()
# Out:
# array([ 6300,  2899,  5350, 25000, 27700,  5700,  7300, 13350, 14600,
#         5250, 10400, 12920, 31900,  5430, 20700, 12710,  5200, 16500,
#         5210, 38100, 12520, 15000,  6180, 20800, 11900, 21500, 12000,
#         4190, 13000, 18500, 29800,  5330, 16600, 19200,  7320,  7000,
#        30500,  6330, 55000, 16200, 19000,  5580, 54000, 16000, 27000,
#         7760, 19600, 20000, 18100, 23000, 13490, 17800,  6650, 29100,
#        21100, 18600,  4340, 19300, 12780, 15800, 29400,  4430, 19400,
#        15900, 26400,  4140, 18300, 17900,  4640, 24000, 13200, 18000,
#        14900, 11500,  9110,  7350, 24500,  9300, 39800, 53500, 15110,
#        34000, 26502,  5990, 13600, 23605, 10780, 13800, 25201,  7070,
#         8700, 18003,  8530, 23100, 17000, 34002,  6980, 20802,  9200,
#        26500, 24802, 28500, 47500, 23500, 23505, 10940, 32100, 53000,
#         6830, 26414,  4160, 19405,  5690, 25900, 24005,  5090, 19500,
# ...

# %%
df['brand'].unique()
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac',
#        'hyundai', 'mazda', 'honda', 'heartland', 'jaguar', 'acura',
#        'harley-davidson', 'audi', 'lincoln', 'lexus', 'nissan', 'land',
#        'maserati', 'peterbilt', 'ram'], dtype=object)

# %%
df[df['brand'] == 'lexus']
# Out:
#      price  brand model  year  ... mileage   color       state country
# 426  55600  lexus    gx  2020  ...    8186  silver     florida     usa
# 503  10840  lexus   mpv  2017  ...   36596   black  california     usa
#
# [2 rows x 9 columns]

# %%
df[df['brand'] == 'audi']
# Out:
#      price brand model  year  ... mileage  color       state country
# 409     25  audi  door  2008  ...  177422  black       texas     usa
# 420      0  audi  door  2005  ...  181896  black  california     usa
# 429  19500  audi    q5  2017  ...   65833   blue       texas     usa
# 444  36400  audi     5  2015  ...   47213  black   wisconsin     usa
#
# [4 rows x 9 columns]

# %%
df[df['brand'] == 'ford']
# Out:
#       price brand   model  year  ... mileage     color           state country
# 1      2899  ford      se  2011  ...  190552    silver       tennessee     usa
# 3     25000  ford    door  2014  ...   64146      blue        virginia     usa
# 9      5250  ford     mpv  2017  ...   63418     black           texas     usa
# 14    20700  ford    door  2013  ...  100757     black        virginia     usa
# 18     5210  ford     mpv  2017  ...   35714     white           texas     usa
# ...     ...   ...     ...   ...  ...     ...       ...             ...     ...
# 2199  13800  ford  fusion  2019  ...   29345     white  north carolina     usa
# 2200  56000  ford     srw  2018  ...   25371     black    pennsylvania     usa
# 2201  13800  ford  fusion  2019  ...   30054    silver  north carolina     usa
# 2202  45800  ford     srw  2018  ...   11173     white    pennsylvania     usa
# 2203  13800  ford  fusion  2019  ...   30902  no_color  north carolina     usa
#
# [1235 rows x 9 columns]

# %%
df[df['country'] == ' usa']
# Out:
#       price      brand    model  year  ... mileage   color       state country
# 0      6300     toyota  cruiser  2008  ...  274117   black  new jersey     usa
# 1      2899       ford       se  2011  ...  190552  silver   tennessee     usa
# 2      5350      dodge      mpv  2018  ...   39590  silver     georgia     usa
# 3     25000       ford     door  2014  ...   64146    blue    virginia     usa
# 4     27700  chevrolet     1500  2018  ...    6654     red     florida     usa
# ...     ...        ...      ...   ...  ...     ...     ...         ...     ...
# 2494   7800     nissan    versa  2019  ...   23609     red  california     usa
# 2495   9200     nissan    versa  2018  ...   34553  silver     florida     usa
# 2496   9200     nissan    versa  2018  ...   31594  silver     florida     usa
# 2497   9200     nissan    versa  2018  ...   32557   black     florida     usa
# 2498   9200     nissan    versa  2018  ...   31371  silver     florida     usa
#
# [2492 rows x 9 columns]

# %%
df[df['brand'] == 'dodge']
# Out:
#       price  brand       model  year  ... mileage     color           state country
# 2      5350  dodge         mpv  2018  ...   39590    silver         georgia     usa
# 5      5700  dodge         mpv  2018  ...   45561     white           texas     usa
# 10    10400  dodge       coupe  2009  ...  107856    orange         georgia     usa
# 48     5580  dodge         mpv  2017  ...   46829      gray           texas     usa
# 94    39800  dodge  challenger  2015  ...    3641     white    pennsylvania     usa
# ...     ...    ...         ...   ...  ...     ...       ...             ...     ...
# 1193  23900  dodge     charger  2019  ...   35248     white         georgia     usa
# 1194  14500  dodge     caravan  2018  ...   40417  no_color         florida     usa
# 1195  23000  dodge     durango  2017  ...   30309      gray        virginia     usa
# 1196  15000  dodge     journey  2018  ...   42303       red  north carolina     usa
# ...

# %%
df[df['color'] == 'orange']
# Out:
#       price      brand       model  ...   color           state  country
# 10    10400      dodge       coupe  ...  orange         georgia      usa
# 141       0      dodge         van  ...  orange            utah      usa
# 316   10900       jeep         mpv  ...  orange        michigan      usa
# 506       0  chevrolet        door  ...  orange        oklahoma      usa
# 814   30000      dodge     charger  ...  orange         ontario   canada
# 845   27900      dodge     charger  ...  orange         florida      usa
# 867    3000      dodge        door  ...  orange       minnesota      usa
# 957   16700      dodge     journey  ...  orange        virginia      usa
# 984   18800      dodge  challenger  ...  orange    pennsylvania      usa
# 1048  16700      dodge     journey  ...  orange       minnesota      usa
# 1064  15900      dodge     charger  ...  orange    pennsylvania      usa
# 1076    800      dodge         van  ...  orange  north carolina      usa
# ...

# %%
df[df['color'] == 'silver']
# Out:
#       price      brand     model  year  ... mileage   color       state country
# 1      2899       ford        se  2011  ...  190552  silver   tennessee     usa
# 2      5350      dodge       mpv  2018  ...   39590  silver     georgia     usa
# 8     14600  chevrolet    malibu  2018  ...    9371  silver     florida     usa
# 24    20800       ford      door  2013  ...  105510  silver    virginia     usa
# 25    11900        gmc      door  2017  ...   28040  silver  california     usa
# ...     ...        ...       ...   ...  ...     ...     ...         ...     ...
# 2481   9200     nissan     versa  2018  ...   39577  silver     florida     usa
# 2484   2300     nissan  frontier  2019  ...       1  silver  california     usa
# 2495   9200     nissan     versa  2018  ...   34553  silver     florida     usa
# 2496   9200     nissan     versa  2018  ...   31594  silver     florida     usa
# 2498   9200     nissan     versa  2018  ...   31371  silver     florida     usa
#
# ...

# %%
df[df["color"] == "red"]
# Out:
#       Unnamed: 0  price      brand  ...           state  country      condition
# 4              4  27700  chevrolet  ...         florida      usa  22 hours left
# 17            17  16500      buick  ...       tennessee      usa  22 hours left
# 32            32  29800  chevrolet  ...    pennsylvania      usa  22 hours left
# 42            42  30500  chevrolet  ...       tennessee      usa  22 hours left
# 43            43   6330       ford  ...           texas      usa    2 days left
# ...          ...    ...        ...  ...             ...      ...            ...
# 2373        2373  15000     nissan  ...        virginia      usa  21 hours left
# 2392        2392  11800     nissan  ...    pennsylvania      usa    3 days left
# 2417        2417    375     nissan  ...  north carolina      usa    2 days left
# 2488        2488   1700     nissan  ...      california      usa    1 days left
# 2494        2494   7800     nissan  ...      california      usa    1 days left
#
# ...

# %%
df[df['brand'] == 'ford']
# Out:
#       price brand   model  year  ... mileage     color           state country
# 1      2899  ford      se  2011  ...  190552    silver       tennessee     usa
# 3     25000  ford    door  2014  ...   64146      blue        virginia     usa
# 9      5250  ford     mpv  2017  ...   63418     black           texas     usa
# 14    20700  ford    door  2013  ...  100757     black        virginia     usa
# 18     5210  ford     mpv  2017  ...   35714     white           texas     usa
# ...     ...   ...     ...   ...  ...     ...       ...             ...     ...
# 2199  13800  ford  fusion  2019  ...   29345     white  north carolina     usa
# 2200  56000  ford     srw  2018  ...   25371     black    pennsylvania     usa
# 2201  13800  ford  fusion  2019  ...   30054    silver  north carolina     usa
# 2202  45800  ford     srw  2018  ...   11173     white    pennsylvania     usa
# 2203  13800  ford  fusion  2019  ...   30902  no_color  north carolina     usa
#
# [1235 rows x 9 columns]

# %%
df[df['country'] == ' canada']
# Out:
#      price      brand    model  year  ... mileage   color    state  country
# 261  33000  chevrolet     1500  2018  ...   52521   white  ontario   canada
# 813  30000      dodge  charger  2019  ...   43294   white  ontario   canada
# 814  30000      dodge  charger  2019  ...   54309  orange  ontario   canada
# 815  30000      dodge  charger  2019  ...   52822   white  ontario   canada
# 816  30000      dodge  charger  2019  ...   45554   white  ontario   canada
# 817  30000      dodge  charger  2019  ...   37538   white  ontario   canada
# 818  29500      dodge  charger  2019  ...   35153     red  ontario   canada
#
# [7 rows x 9 columns]

# %%
df[df['title_status'] == 'clean vehicle']
# Out:
#       price      brand    model  year  ... mileage   color       state country
# 0      6300     toyota  cruiser  2008  ...  274117   black  new jersey     usa
# 1      2899       ford       se  2011  ...  190552  silver   tennessee     usa
# 2      5350      dodge      mpv  2018  ...   39590  silver     georgia     usa
# 3     25000       ford     door  2014  ...   64146    blue    virginia     usa
# 4     27700  chevrolet     1500  2018  ...    6654     red     florida     usa
# ...     ...        ...      ...   ...  ...     ...     ...         ...     ...
# 2494   7800     nissan    versa  2019  ...   23609     red  california     usa
# 2495   9200     nissan    versa  2018  ...   34553  silver     florida     usa
# 2496   9200     nissan    versa  2018  ...   31594  silver     florida     usa
# 2497   9200     nissan    versa  2018  ...   32557   black     florida     usa
# 2498   9200     nissan    versa  2018  ...   31371  silver     florida     usa
#
# [2336 rows x 9 columns]

# %%
df[df['title_status'] == 'salvage insurance']
# Out:
#       Unnamed: 0  price      brand  ...           state  country      condition
# 141          141      0      dodge  ...            utah      usa    2 days left
# 144          144      0      dodge  ...            utah      usa    2 days left
# 188          188    175   chrysler  ...  north carolina      usa    3 days left
# 206          206     25  chevrolet  ...        kentucky      usa    3 days left
# 209          209     25   chrysler  ...   massachusetts      usa    3 days left
# ...          ...    ...        ...  ...             ...      ...            ...
# 2429        2429   4800     nissan  ...           texas      usa  17 hours left
# 2434        2434   3000     nissan  ...  south carolina      usa    2 days left
# 2440        2440   5475     nissan  ...     connecticut      usa    2 days left
# 2445        2445   1950     nissan  ...      california      usa    2 days left
# 2453        2453   1500     nissan  ...        maryland      usa    3 days left
#
# ...

# %%
df.groupby('model').mean()['price'].sort_values(ascending = False).plot.line(figsize = (25,25))

# %%
df.groupby('model').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (25,45))

# %%
df.groupby('brand').mean()['price'].sort_values(ascending = False).plot.line(figsize = (25,25))

# %%
df.groupby('brand').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (25,25))

# %%
df.groupby('brand').mean()['mileage'].sort_values(ascending = False).plot.line(figsize = (25,25))

# %%
df.groupby('brand').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (25,25))

# %%
df.groupby('state').mean()['price'].sort_values(ascending = False).plot.line(figsize = (5,15))

# %%
df.groupby('state').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (15,15))

# %%
df.groupby('country').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (5,10))

# %%
df.groupby('country').mean()['price'].sort_values(ascending = False).plot.line(figsize = (5,10))

# %%
df.groupby('state').mean()['mileage'].sort_values(ascending = False).plot.bar(figsize = (15,10))

# %%
df.groupby('mileage').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (150,150))

# %%
df.groupby('mileage').mean()['price'].sort_values(ascending = False).plot.line(figsize = (150,150))

# %%
df.groupby('price').mean()['mileage'].sort_values(ascending = False).plot.bar(figsize = (15,15))

# %%
df.groupby('price').mean()['mileage'].sort_values(ascending = False).plot.line(figsize = (15,15))

# %%
df.groupby('brand').mean()['mileage'].sort_values(ascending = False).plot.bar(figsize = (15,10))

# %%
df.groupby('brand').mean()['mileage'].sort_values(ascending = False).plot.line(figsize = (15,10))

# %%
df.groupby('title_status').mean()['year'].sort_values(ascending = False).plot.line(figsize = (15,10))

# %%
df.groupby('title_status').mean()['year'].sort_values(ascending = False).plot.bar(figsize = (5,10))

# %%
df.groupby('model').mean()['year'].sort_values(ascending = False).plot.line(figsize = (15,10))

# %%
df.groupby('model').mean()['year'].sort_values(ascending = True).head(25).plot.bar(figsize = (15,10))

# %%
df.groupby('model').mean()['year'].sort_values(ascending = False).plot.line(figsize = (5,10))

# %%
df['year'].max()
# Out:
# 2020

# %%
df['year'].min()
# Out:
# 1973

# %%
df_silver = df[df['color'] == 'silver']

# %%
data = []

for year in df_silver['year'].unique():
    data.append([year , len(df_silver[df_silver['year']  == year])])

pd.DataFrame(data,columns = ['year','freq']).sort_values(by='year', ascending=False).head().plot(x = 'year', y = 'freq', kind = 'bar', figsize = (5,5))

# %%
df_red = df[df['color'] == 'red']
data = []

for year in df_red['year'].unique():
    data.append([year , len(df_red[df_red['year']  == year])])

pd.DataFrame(data,columns = ['year','freq']).sort_values(by='year', ascending=False).head().plot(x = 'year', y = 'freq', kind = 'bar', figsize = (5,5))

# %%
df_white = df[df['color'] == 'white']
data = []

for year in df_white['year'].unique():
    data.append([year , len(df_white[df_white['year']  == year])])

pd.DataFrame(data,columns = ['year','freq']).sort_values(by='year', ascending=False).plot(x = 'year', y = 'freq', kind = 'bar', figsize = (5,5))

# %%
df.groupby('mileage').mean()['price'].head().sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('brand').mean()['mileage'].head().sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('price').mean()['mileage'].head().sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('color').mean()['price'].head().sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('year').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df_black = df[df['color'] == 'black']
data = []

for year in df_black['year'].unique():
    data.append([year , len(df_black[df_black['year']  == year])])
pd.DataFrame(data,columns = ['year','freq']).sort_values(by='year', ascending=False).head().plot(x = 'year', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# **Q1 . Top 5 car brands in terms of number of cars**

# %%
data = []

for brand in df['brand'].unique():
    data.append([brand , len(df[df['brand']  == brand])])

pd.DataFrame(data,columns = ['brand','freq']).sort_values(by='freq', ascending=False).head().plot(x = 'brand', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# **Q2. Car brand based on the frequency of the car**

# %%
data = []

for brand in df['brand'].unique():
    data.append([brand , len(df[df['brand']  == brand])])

pd.DataFrame(data,columns = ['brand','freq']).sort_values(by='freq', ascending=False).plot(x = 'brand', y = 'freq', kind = 'bar', figsize = (10,5))

# %% [markdown]
# **Q3. Car Industry Trend**

# %%
data = []

for year in df['year'].unique():
    data.append([year , len(df[df['year']  == year])])

pd.DataFrame(data,columns = ['year','freq']).sort_values(by='year', ascending=True).plot(x = 'year', y = 'freq', kind = 'line', figsize = (15,5))

# %% [markdown]
# **Q4 Most popular car color **

# %%
data = []

for color  in df['color'].unique():
    data.append([year , len(df[df['color']  == color])])

pd.DataFrame(data,columns = ['color','freq']).sort_values(by='color', ascending = True).plot(x = 'color', y = 'freq', kind = 'bar', figsize = (20,5))

# %% [markdown]
# **Q5. Which car brands having maximum price**

# %%
df.groupby('brand').mean()['price'].sort_values(ascending = False).plot.bar(15,5)

# %% [markdown]
# **Q6. Which State is having a most popular car**

# %%
df.groupby('state').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('state').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('model').mean()['price'].sort_values(ascending = False).head(10).plot.bar(figsize = (5,10))

# %%
df.groupby('model').mean()['price'].sort_values(ascending = False).head(10).plot.line(figsize = (5,10))

# %%
df.groupby('year').mean()['price'].sort_values(ascending = False).plot.bar(figsize = (15,5))

# %%
df.groupby('year').mean()['price'].sort_values(ascending = False).plot.line(figsize = (15,5))
